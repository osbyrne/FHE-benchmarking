# %% [markdown]
# # FHE libraries benchmarking
#
# We will be comparing [Concrete](https://docs.zama.ai/concrete) and [OpenFHE](https://github.com/openfheorg/openfhe-python) in speed over four categories:
# - encryption
# - addition
# - multiplication
# - decryption
#
# We will run these programs for a wide range of values. For each value, we will average ten runs to remove statistical randomness, though we do not know if ten runs is sufficient.

# %% [markdown]
# # Concrete

# %% [markdown]
# ## Encryption

# %%
import time
import matplotlib.pyplot as plt
from random import randint
from typing import List, Final, Tuple
from concrete import fhe

def add(x: int, y: int) -> int:
    return x + y

num_runs: Final[int] = 1
encryption_execution_times: List[float] = []
input_sizes: List[int] = [10, 100, 1000, 10000]

compiler = fhe.Compiler(add, {"x": "encrypted", "y": "encrypted"})

for size in input_sizes:
    total_time: float = 0
    for _ in range(num_runs):
        inputset: List[Tuple[int, int]] = [(randint(0, size), randint(0, size)) for _ in range(size)]
        circuit = compiler.compile(inputset)
        start_time: float = time.time()
        for input in inputset:
            circuit.encrypt(input[0], input[1])
        end_time: float = time.time()
        execution_time = end_time - start_time
        total_time += execution_time

    average_time = total_time / num_runs
    encryption_execution_times.append(average_time)

# Plot the charts
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, encryption_execution_times, label='Encryption Time')
plt.xlabel('Input Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Times')
plt.legend()
plt.show()

# %% [markdown]
# ## Addition

# %%
import time
import matplotlib.pyplot as plt
from random import randint
from typing import List, Final, Tuple
from concrete import fhe

def add(x: int, y: int) -> int:
    return x + y

num_runs: Final[int] = 1
encryption_execution_times: List[float] = []
input_sizes: List[int] = [10, 100, 1000, 10000]

compiler = fhe.Compiler(add, {"x": "encrypted", "y": "encrypted"})

addition_execution_times: List[float] = []

for size in input_sizes:
    total_time: float = 0
    for _ in range(num_runs):
        inputset: List[Tuple[int, int]] = [(randint(0, size), randint(0, size)) for _ in range(size)]
        circuit = compiler.compile(inputset)
        encrypted_inputs = [circuit.encrypt(input[0], input[1]) for input in inputset]
        start_time: float = time.time()
        for encrypted_input in encrypted_inputs:
            circuit.run(encrypted_input)
        end_time: float = time.time()
        execution_time = end_time - start_time
        total_time += execution_time

    average_time = total_time / num_runs
    addition_execution_times.append(average_time)

# Plot the charts
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, addition_execution_times, label='Addition Time')
plt.xlabel('Input Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Times')
plt.legend()
plt.show()

# %% [markdown]
# ## Multiplication

# %%
import time
from random import randint
from typing import List, Final, Tuple
from concrete import fhe

import matplotlib.pyplot as plt

def multiply(x: int, y: int) -> int:
    return x * y

num_runs: Final[int] = 1
multiplication_execution_times: List[float] = []
input_sizes: List[int] = [1, 10]

compiler = fhe.Compiler(multiply, {"x": "encrypted", "y": "encrypted"})

for size in input_sizes:
    total_time: float = 0
    for _ in range(num_runs):
        inputset: List[Tuple[int, int]] = [(randint(0, size), randint(0, size)) for _ in range(size)]
        circuit = compiler.compile(inputset)
        encrypted_inputs = [circuit.encrypt(input[0], input[1]) for input in inputset]
        start_time: float = time.time()
        for encrypted_input in encrypted_inputs:
            circuit.run(encrypted_input)
        end_time: float = time.time()
        execution_time = end_time - start_time
        total_time += execution_time

    average_time = total_time / num_runs
    multiplication_execution_times.append(average_time)

# Plot the charts
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, multiplication_execution_times, label='Multiplication Time')
plt.xlabel('Input Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Times')
plt.legend()
plt.show()

# %% [markdown]
# ## Decryption

# %%
import time
from random import randint
from typing import List, Final, Tuple
from concrete import fhe

import matplotlib.pyplot as plt

def multiply(x: int, y: int) -> int:
    return x * y

num_runs: Final[int] = 1
decryption_execution_times: List[float] = []
input_sizes: List[int] = [1, 10]

compiler = fhe.Compiler(multiply, {"x": "encrypted", "y": "encrypted"})

for size in input_sizes:
    total_time: float = 0
    for _ in range(num_runs):
        inputset: List[Tuple[int, int]] = [(randint(0, size), randint(0, size)) for _ in range(size)]
        circuit = compiler.compile(inputset)
        encrypted_inputs = [circuit.encrypt(input[0], input[1]) for input in inputset]
        start_time: float = time.time()
        for encrypted_input in encrypted_inputs:
            encrypted_output = circuit.run(encrypted_input)
            circuit.decrypt(encrypted_output)
        end_time: float = time.time()
        execution_time = end_time - start_time
        total_time += execution_time

    average_time = total_time / num_runs
    decryption_execution_times.append(average_time)

# Plot the charts
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, decryption_execution_times, label='Decryption Time')
plt.xlabel('Input Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Decryption Times')
plt.legend()
plt.show()

# %% [markdown]
# # OpenFHE

# %% [markdown]
# ## Encryption

# %%
import time
from openfhe import PKESchemeFeature, CCParamsBFVRNS, GenCryptoContext

# Define the encryption function
def encrypt_with_openfhe(vector_of_ints: list[int]) -> float:
    parameters = CCParamsBFVRNS()
    parameters.SetPlaintextModulus(65537)
    parameters.SetMultiplicativeDepth(2)

    crypto_context = GenCryptoContext(parameters)
    crypto_context.Enable(PKESchemeFeature.PKE)
    crypto_context.Enable(PKESchemeFeature.KEYSWITCH)
    crypto_context.Enable(PKESchemeFeature.LEVELEDSHE)

    key_pair = crypto_context.KeyGen()
    plaintext = crypto_context.MakePackedPlaintext(vector_of_ints)
    start_time: float = time.time()
    ciphertext = crypto_context.Encrypt(key_pair.publicKey, plaintext)
    end_time: float = time.time()
    return end_time - start_time

# Measure encryption times for different input sizes
openfhe_encryption_times: List[float] = []
for size in input_sizes:
    vector_of_ints: List[int] = [randint(0, size) for _ in range(size)]
    encryption_time:float = encrypt_with_openfhe(vector_of_ints)
    openfhe_encryption_times.append(encryption_time)

# Plot the charts
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, openfhe_encryption_times, label='OpenFHE Encryption Time')
plt.xlabel('Input Size')
plt.ylabel('Encryption Time (seconds)')
plt.title('OpenFHE Encryption Times')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import time
# ----> 2 from openfhe import PKESchemeFeature, CCParamsBFVRNS, GenCryptoContext
#       4 # Define the encryption function
#       5 def encrypt_with_openfhe(vector_of_ints: list[int]) -> float:
#
# File ~/.local/lib/python3.10/site-packages/openfhe/__init__.py:1
# ----> 1 from .openfhe import *
#
# ImportError: libOPENFHEpke.so.1: cannot open shared object file: No such file or directory

# %% [markdown]
# ## Addition

# %%
# TODO finish this

# %% [markdown]
# ## Multiplication

# %%
# TODO finish this

# %% [markdown]
# ## Decryption

# %%
# TODO finish this
